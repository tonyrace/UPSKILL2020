# %%
import pandas as pd
import csv

# %%
acunetix = pd.read_csv('data/acunetixnew.csv')
netsparker = pd.read_csv('data/netsparkernew.csv')
w3af = pd.read_csv('data/w3afnew.csv')

# %%
df_row_reindex = pd.concat([acunetix, netsparker])

# %%
df_row_reindex['tool']
# Out:
# 0         acunetix
# 1         acunetix
# 2         acunetix
# 3         acunetix
# 4         acunetix
#            ...
# 7309    netsparker
# 7310    netsparker
# 7311    netsparker
# 7312    netsparker
# 7313    netsparker
# Name: tool, Length: 13853, dtype: object

# %%
df = pd.concat([df_row_reindex,w3af])

# %%
df.to_csv('data/data.csv',index=True)

# %%
df
# Out:
#               host      tool indent user                        time method  \
# 0     192.168.4.25  acunetix      -    -  22/Dec/2016:16:30:52 +0300   POST
# 1     192.168.4.25  acunetix      -    -  22/Dec/2016:16:29:05 +0300   POST
# 2     192.168.4.25  acunetix      -    -  22/Dec/2016:16:28:53 +0300   POST
# 3     192.168.4.25  acunetix      -    -  22/Dec/2016:16:32:50 +0300   POST
# 4     192.168.4.25  acunetix      -    -  22/Dec/2016:16:29:13 +0300   POST
# ...            ...       ...    ...  ...                         ...    ...
# 3929  192.168.4.25      W3AF      -    -  22/Dec/2016:22:55:47 +0300   POST
# 3930  192.168.4.25      W3AF      -    -  22/Dec/2016:23:04:32 +0300    GET
# 3931  192.168.4.25      W3AF      -    -  22/Dec/2016:23:04:32 +0300    GET
# 3932  192.168.4.25      W3AF      -    -  22/Dec/2016:23:04:32 +0300    GET
# 3933  192.168.4.25      W3AF      -    -  22/Dec/2016:23:04:32 +0300    GET
#
#                                request_path status  size  \
# 0         /administrator/index.php HTTP/1.1    303   382
# 1     /index.php/component/search/ HTTP/1.1    500  2011
# 2     /index.php/component/search/ HTTP/1.1    303   374
# 3     /index.php/component/search/ HTTP/1.1    200  3054
# 4     /index.php/component/search/ HTTP/1.1    200  3056
# ...                                     ...    ...   ...
# 3929               /DVWA/login.php HTTP/1.1    302   385
# 3930       /DVWA/dvwa/css/main.css HTTP/1.1    200  1429
# 3931    /DVWA/dvwa/images/logo.png HTTP/1.1    304   180
# 3932     /DVWA/dvwa/js/dvwaPage.js HTTP/1.1    200   762
# 3933               /DVWA/index.php HTTP/1.1    200  2021
#
#                                   referer  \
# 0               http://192.168.4.161/DVWA
# 1                                       -
# 2               http://192.168.4.161/DVWA
# 3               http://192.168.4.161/DVWA
# 4                                       -
# ...                                   ...
# 3929  http://192.168.4.161/DVWA/login.php
# 3930  http://192.168.4.161/DVWA/index.php
# 3931  http://192.168.4.161/DVWA/index.php
# 3932  http://192.168.4.161/DVWA/index.php
# 3933  http://192.168.4.161/DVWA/login.php
#
#                                                   agent
# 0     Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...
# 1     Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...
# 2     Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...
# 3     Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...
# 4     Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...
# ...                                                 ...
# 3929  Mozilla/5.0 (Windows NT 10.0; WOW64; rv:50.0) ...
# 3930  Mozilla/5.0 (Windows NT 10.0; WOW64; rv:50.0) ...
# 3931  Mozilla/5.0 (Windows NT 10.0; WOW64; rv:50.0) ...
# 3932  Mozilla/5.0 (Windows NT 10.0; WOW64; rv:50.0) ...
# 3933  Mozilla/5.0 (Windows NT 10.0; WOW64; rv:50.0) ...
#
# [17787 rows x 11 columns]
