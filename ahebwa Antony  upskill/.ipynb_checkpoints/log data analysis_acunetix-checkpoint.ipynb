# %%
import os
import sys
import argparse
import csv
import re
from io import StringIO
import pandas as pd

# %%
parts = [
    r'"(?P<host>\S+)',                   # host %h
    r'(?P<indent>\S+)',                             # indent %l (unused)
    r'(?P<user>\S+)',                   # user %u
    r'\[(?P<time>.+)\]',                # time %t
    r'"(?P<method>\w+)',                #action
    r'(?P<request_path>.+)"',               # request "%r"
    r'(?P<status>[0-9]+)',              # status %>s
    r'(?P<size>\S+)',                   # size %b (careful, can be '-')
    r'"(?P<referer>.*)"',               # referer "%{Referer}i"
    r'"(?P<agent>.*)"',                 # user agent "%{User-agent}i"
]
pattern = re.compile(r'\s+'.join(parts)+r'\s*\Z')

# %%
# LOG_REGEX = '(?P<ip>[(\d\.)]+) (?P<indent>\S+) (?P<user>\S+) \[(?P<date>.*?) -(.*?)\] "(?P<method>\w+) (?P<request_path>.*?) HTTP/(?P<http_version>.*?)" (?P<status_code>\d+) (?P<response_size>\d+) "(?P<referrer>.*?)" "(?P<user_agent>.*?)"'

# %%
# compiled = re.compile(LOG_REGEX)

# %%
f = open("data/acunetix.txt","r")
contents = f.readlines()
data = []
for line in contents:
    m = pattern.match(line)
    res = m.groupdict()
    data.append(res)

# %%
data
# Out:
# [{'host': '192.168.4.25',
#   'indent': '-',
#   'user': '-',
#   'time': '22/Dec/2016:16:30:52 +0300',
#   'method': 'POST',
#   'request_path': '/administrator/index.php HTTP/1.1',
#   'status': '303',
#   'size': '382',
#   'referer': 'http://192.168.4.161/DVWA',
#   'agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.21 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.21"'},
#  {'host': '192.168.4.25',
#   'indent': '-',
#   'user': '-',
#   'time': '22/Dec/2016:16:29:05 +0300',
#   'method': 'POST',
#   'request_path': '/index.php/component/search/ HTTP/1.1',
#   'status': '500',
#   'size': '2011',
#   'referer': '-',
#   'agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.21 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.21"'},
#  {'host': '192.168.4.25',
#   'indent': '-',
#   'user': '-',
#   'time': '22/Dec/2016:16:28:53 +0300',
#   'method': 'POST',
#   'request_path': '/index.php/component/search/ HTTP/1.1',
#   'status': '303',
#   'size': '374',
#   'referer': 'http://192.168.4.161/DVWA',
#   'agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.21 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.21"'},
#  {'host': '192.168.4.25',
#   'indent': '-',
#   'user': '-',
#   'time': '22/Dec/2016:16:32:50 +0300',
#   'method': 'POST',
#   'request_path': '/index.php/component/search/ HTTP/1.1',
#   'status': '200',
#   'size': '3054',
#   'referer': 'http://192.168.4.161/DVWA',
#   'agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.21 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.21"'},
#  {'host': '192.168.4.25',
#   'indent': '-',
#   'user': '-',
#   'time': '22/Dec/2016:16:29:13 +0300',
#   'method': 'POST',
#   'request_path': '/index.php/component/search/ HTTP/1.1',
#   'status': '200',
#   'size': '3056',
#   'referer': '-',
#   'agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.21 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.21"'},
#  {'host': '192.168.4.25',
#   'indent': '-',
#   'user': '-',
#   'time': '22/Dec/2016:16:29:33 +0300',
#   'method': 'GET',
#   'request_path': '/index.php/component/search/?searchword=&ordering=alpha&searchphrase=all&areas[0]=newsfeeds HTTP/1.1',
#   'status': '200',
#   'size': '3122',
#   'referer': 'http://192.168.4.161/DVWA',
#   'agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.21 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.21"'},
#  {'host': '192.168.4.25',
#   'indent': '-',
#   'user': '-',
#   'time': '22/Dec/2016:16:24:39 +0300',
#   'method': 'POST',
#   'request_path': '/index.php/component/search/ HTTP/1.1',
#   'status': '303',
#   'size': '412',
#   'referer': '-',
#   'agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.21 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.21"'},
#  {'host': '192.168.4.25',
#   'indent': '-',
#   'user': '-',
#   'time': '22/Dec/2016:16:28:52 +0300',
#   'method': 'POST',
#   'request_path': '/index.php/component/search/ HTTP/1.1',
#   'status': '303',
#   'size': '377',
#   'referer': 'http://192.168.4.161/DVWA',
#   'agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.21 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.21"'},
#  {'host': '192.168.4.25',
#   'indent': '-',
#   'user': '-',
#   'time': '22/Dec/2016:16:28:58 +0300',
#   'method': 'POST',
#   'request_path': '/index.php/component/search/ HTTP/1.1',
#   'status': '200',
#   'size': '3052',
#   'referer': '-',
#   'agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.21 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.21"'},
#  {'host': '192.168.4.25',
#   'indent': '-',
#   'user': '-',
#   'time': '22/Dec/2016:16:21:56 +0300',
#   'method': 'POST',
#   'request_path': '/index.php/component/search/ HTTP/1.1',
#   'status': '303',
#   'size': '376',
#   'referer': 'http://192.168.4.161/DVWA',
#   'agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.21 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.21"'},
#  {'host': '192.168.4.25',
#   'indent': '-',
#   'user': '-',
#   'time': '22/Dec/2016:16:20:49 +0300',
#   'method': 'POST',
#   'request_path': '/index.php/component/search/ HTTP/1.1',
#   'status': '303',
#   'size': '376',
#   'referer': 'http://192.168.4.161/DVWA',
#   'agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.21 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.21"'},
#  {'host': '192.168.4.25',
#   'indent': '-',
#   'user': '-',
#   'time': '22/Dec/2016:16:18:20 +0300',
#   'method': 'GET',
#   'request_path': '/templates/beez_20/css/personal.css HTTP/1.1',
#   'status': '200',
#   'size': '4918',
#   'referer': "http://192.168.4.161/?wvstest=javascript:domxssExecutionSink(1,%22'%5C%22%3E%3Cxsstag%3E()locxss%22)",
#   'agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.21 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.21"'},
#  {'host': '192.168.4.25',
#   'indent': '-',
#   'user': '-',
#   'time': '22/Dec/2016:16:28:11 +0300',
#   'method': 'POST',
#   'request_path': '/index.php/component/search/ HTTP/1.1',
#   'status': '303',
#   'size': '378',
#   'referer': 'http://192.168.4.161/DVWA',
#   'agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.21 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.21"'},
#  {'host': '192.168.4.25',
#   'indent': '-',
#   'user': '-',
#   'time': '22/Dec/2016:16:25:15 +0300',
#   'method': 'POST',
#   'request_path': '/index.php/component/search/ HTTP/1.1',
#   'status': '303',
#   'size': '372',
#   'referer': '-',
#   'agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.21 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.21"'},
#  {'host': '192.168.4.25',
#   'indent': '-',
#   'user': '-',
#   'time': '22/Dec/2016:16:26:04 +0300',
#   'method': 'POST',
#   'request_path': '/index.php/component/search/ HTTP/1.1',
#   'status': '303',
#   'size': '371',
#   'referer': 'http://192.168.4.161/DVWA',
#   'agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.21 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.21"'},
#  {'host': '192.168.4.25',
#   'indent': '-',
#   'user': '-',
#   'time': '22/Dec/2016:16:27:34 +0300',
#   'method': 'POST',
#   'request_path': '/index.php/component/search/ HTTP/1.1',
#   'status': '303',
#   'size': '413',
#   'referer': 'http://192.168.4.161/DVWA',
#   'agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.21 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.21"'},
#  {'host': '192.168.4.25',
#   'indent': '-',
#   'user': '-',
#   'time': '22/Dec/2016:16:28:41 +0300',
#   'method': 'POST',
#   'request_path': '/index.php/component/search/ HTTP/1.1',
#   'status': '500',
#   'size': '2011',
#   'referer': '-',
#   'agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.21 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.21"'},
#  {'host': '192.168.4.25',
#   'indent': '-',
#   'user': '-',
#   'time': '22/Dec/2016:16:25:45 +0300',
#   'method': 'POST',
#   'request_path': '/index.php/component/search/ HTTP/1.1',
#   'status': '200',
#   'size': '3086',
#   'referer': 'http://192.168.4.161/DVWA',
#   'agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.21 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.21"'},
#  {'host': '192.168.4.25',
#   'indent': '-',
#   'user': '-',
#   'time': '22/Dec/2016:16:20:01 +0300',
#   'method': 'GET',
#   'request_path': "/index.php/2-uncategorised/1--1'%20OR%202%2b196-196-1=0%2b0%2b0%2b1%20or%20'01Fg5alL'=' HTTP/1.1",
#   'status': '200',
#   'size': '3304',
#   'referer': 'http://192.168.4.161/DVWA',
#   'agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.21 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.21"'},
#  {'host': '192.168.4.25',
#   'indent': '-',
#   'user': '-',
#   'time': '22/Dec/2016:16:39:05 +0300',
#   'method': 'POST',
#   'request_path': '/index.php/component/users/?task=user.login HTTP/1.1',
#   'status': '303',
#   'size': '385',
#   'referer': 'http://192.168.4.161/DVWA',
#   'agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.21 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.21"'},
#  {'host': '192.168.4.25',
#   'indent': '-',
#   'user': '-',
#   'time': '22/Dec/2016:16:37:41 +0300',
#   'method': 'POST',
#   'request_path': '/index.php/component/users/?task=/etc/passwd HTTP/1.1',
#   'status': '200',
#   'size': '2767',
#   'referer': 'http://192.168.4.161/DVWA',
#   'agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.21 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.21"'},
#  {'host': '192.168.4.25',
#   'indent': '-',
#   'user': '-',
#   'time': '22/Dec/2016:16:40:05 +0300',
#   'method': 'POST',
#   'request_path': '/index.php/component/users/?task=user.login HTTP/1.1',
#   'status': '303',
#   'size': '385',
#   'referer': 'http://192.168.4.161/DVWA',
#   'agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.21 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.21"'},
#  {'host': '192.168.4.25',
#   'indent': '-',
#   'user': '-',
#   'time': '22/Dec/2016:16:21:23 +0300',
#   'method': 'POST',
#   'request_path': '/index.php/component/search/ HTTP/1.1',
#   'status': '303',
#   'size': '393',
#   'referer': 'http://192.168.4.161/DVWA',
#   'agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.21 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.21"'},
#  {'host': '192.168.4.25',
#   'indent': '-',
#   'user': '-',
#   'time': '22/Dec/2016:16:34:32 +0300',
#   'method': 'POST',
#   'request_path': '/index.php/component/search/ HTTP/1.1',
#   'status': '303',
#   'size': '396',
#   'referer': 'http://192.168.4.161/DVWA',
#   'agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.21 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.21"'},
#  {'host': '192.168.4.25',
#   'indent': '-',
#   'user': '-',
#   'time': '22/Dec/2016:16:36:25 +0300',
#   'method': 'POST',
#   'request_path': '/index.php/component/search/ HTTP/1.1',
#   'status': '303',
#   'size': '4459',
#   'referer': 'http://192.168.4.161/DVWA',
#   'agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.21 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.21"'},
#  {'host': '192.168.4.25',
#   'indent': '-',
#   'user': '-',
#   'time': '22/Dec/2016:16:20:43 +0300',
#   'method': 'POST',
#   'request_path': '/index.php/component/search/ HTTP/1.1',
#   'status': '303',
#   'size': '380',
#   'referer': '-',
#   'agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.21 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.21"'},
#  {'host': '192.168.4.25',
#   'indent': '-',
#   'user': '-',
#   'time': '22/Dec/2016:16:30:03 +0300',
#   'method': 'POST',
#   'request_path': '/administrator/index.php HTTP/1.1',
#   'status': '500',
#   'size': '1522',
#   'referer': 'http://192.168.4.161/DVWA',
#   'agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.21 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.21"'},
#  {'host': '192.168.4.25',
#   'indent': '-',
#   'user': '-',
#   'time': '22/Dec/2016:16:18:11 +0300',
#   'method': 'GET',
#   'request_path': '/$sitepreview/localhost:2006/Wizard/ HTTP/1.1',
#   'status': '404',
#   'size': '526',
#   'referer': '-',
#   'agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.21 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.21"'},
#  {'host': '192.168.4.25',
#   'indent': '-',
#   'user': '-',
#   'time': '22/Dec/2016:16:18:19 +0300',
#   'method': 'GET',
#   'request_path': '/media/system/js/mootools-more.js HTTP/1.1',
#   'status': '200',
#   'size': '68451',
#   'referer': "http://192.168.4.161/index.php/component/users/?wvstest=javascript:domxssExecutionSink(1,%22'%5C%22%3E%3Cxsstag%3E()locxss%22)&view=reset",
#   'agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.21 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.21"'},
#  {'host': '192.168.4.25',
#   'indent': '-',
#   'user': '-',
#   'time': '22/Dec/2016:16:34:28 +0300',
#   'method': 'GET',
#   'request_path': '/index.php/component/search/?ordering=newest%26n944645=v964541&searchphrase=all&searchword= HTTP/1.1',
#   'status': '200',
#   'size': '3123',
#   'referer': '-',
#   'agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.21 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.21"'},
#  {'host': '192.168.4.25',
#   'indent': '-',
#   'user': '-',
#   'time': '22/Dec/2016:16:18:27 +0300',
#   'method': 'GET',
#   'request_path': '/templates/beez_20/css/print.css HTTP/1.1',
#   'status': '200',
#   'size': '2149',
#   'referer': "http://192.168.4.161/index.php/component/users/?wvstest=javascript:domxssExecutionSink(1,%22'%5C%22%3E%3Cxsstag%3E()locxss%22)",
#   'agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.21 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.21"'},
#  {'host': '192.168.4.25',
#   'indent': '-',
#   'user': '-',
#   'time': '22/Dec/2016:16:36:26 +0300',
#   'method': 'GET',
#   'request_path': '/index.php/component/search/?ordering=newest&searchphrase=any&searchword=%f0\'\'%f0\\"\\" HTTP/1.1',
#   'status': '200',
#   'size': '3148',
#   'referer': 'http://192.168.4.161/DVWA',
#   'agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.21 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.21"'},
#  {'host': '192.168.4.25',
#   'indent': '-',
#   'user': '-',
#   'time': '22/Dec/2016:16:33:06 +0300',
#   'method': 'POST',
#   'request_path': '/index.php/component/search/ HTTP/1.1',
#   'status': '200',
#   'size': '3052',
#   'referer': 'http://192.168.4.161/DVWA',
#   'agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.21 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.21"'},
#  {'host': '192.168.4.25',
#   'indent': '-',
#   'user': '-',
#   'time': '22/Dec/2016:16:35:46 +0300',
#   'method': 'POST',
#   'request_path': '/index.php HTTP/1.1',
#   'status': '303',
#   'size': '368',
#   'referer': 'http://192.168.4.161/DVWA',
#   'agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.21 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.21"'},
#  {'host': '192.168.4.25',
#   'indent': '-',
#   'user': '-',
#   'time': '22/Dec/2016:16:30:08 +0300',
#   'method': 'POST',
#   'request_path': '/index.php/component/search/ HTTP/1.1',
#   'status': '200',
#   'size': '3085',
#   'referer': '-',
#   'agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.21 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.21"'},
#  {'host': '192.168.4.25',
#   'indent': '-',
#   'user': '-',
#   'time': '22/Dec/2016:16:34:17 +0300',
#   'method': 'POST',
#   'request_path': '/index.php/component/search/ HTTP/1.1',
#   'status': '200',
#   'size': '3056',
#   'referer': 'http://192.168.4.161/DVWA',
#   'agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.21 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.21"'},
#  {'host': '192.168.4.25',
#   'indent': '-',
#   'user': '-',
#   'time': '22/Dec/2016:16:36:34 +0300',
#   'method': 'POST',
#   'request_path': '/index.php/component/search/ HTTP/1.1',
#   'status': '303',
#   'size': '371',
#   'referer': 'http://192.168.4.161/DVWA',
#   'agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.21 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.21"'},
#  {'host': '192.168.4.25',
#   'indent': '-',
#   'user': '-',
#   'time': '22/Dec/2016:16:38:51 +0300',
#   'method': 'POST',
#   'request_path': '/index.php/component/users/?task=registration.register HTTP/1.1',
#   'status': '200',
#   'size': '237',
#   'referer': 'http://192.168.4.161/DVWA',
#   'agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.21 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.21"'},
#  {'host': '192.168.4.25',
#   'indent': '-',
#   'user': '-',
#   'time': '22/Dec/2016:16:23:03 +0300',
#   'method': 'POST',
#   'request_path': '/index.php/component/search/ HTTP/1.1',
#   'status': '303',
#   'size': '355',
#   'referer': 'http://192.168.4.161/DVWA',
#   'agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.21 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.21"'},
#  {'host': '192.168.4.25',
#   'indent': '-',
#   'user': '-',
#   'time': '22/Dec/2016:16:21:43 +0300',
#   'method': 'POST',
#   'request_path': '/index.php/component/search/ HTTP/1.1',
#   'status': '303',
#   'size': '409',
#   'referer': '-',
#   'agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.21 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.21"'},
#  {'host': '192.168.4.25',
#   'indent': '-',
#   'user': '-',
#   'time': '22/Dec/2016:16:18:46 +0300',
#   'method': 'POST',
#   'request_path': '/index.php HTTP/1.1',
#   'status': '200',
#   'size': '339',
#   'referer': '-',
#   'agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.21 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.21"'},
#  {'host': '192.168.4.25',
#   'indent': '-',
#   'user': '-',
#   'time': '22/Dec/2016:16:30:52 +0300',
#   'method': 'POST',
#   'request_path': '/DVWA/login.php HTTP/1.1',
#   'status': '302',
#   'size': '469',
#   'referer': 'http://192.168.4.161/DVWA',
#   'agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.21 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.21"'},
#  {'host': '192.168.4.25',
#   'indent': '-',
#   'user': '-',
#   'time': '22/Dec/2016:16:32:02 +0300',
#   'method': 'POST',
#   'request_path': '/index.php/component/search/ HTTP/1.1',
#   'status': '200',
#   'size': '3056',
#   'referer': 'http://192.168.4.161/DVWA',
#   'agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.21 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.21"'},
#  {'host': '192.168.4.25',
#   'indent': '-',
#   'user': '-',
#   'time': '22/Dec/2016:16:39:12 +0300',
#   'method': 'POST',
#   'request_path': '/index.php/component/users/?task=registration.register HTTP/1.1',
#   'status': '200',
#   'size': '237',
#   'referer': 'http://192.168.4.161/DVWA',
#   'agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.21 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.21"'},
#  {'host': '192.168.4.25',
#   'indent': '-',
#   'user': '-',
#   'time': '22/Dec/2016:16:32:44 +0300',
#   'method': 'POST',
#   'request_path': '/administrator/index.php HTTP/1.1',
#   'status': '303',
#   'size': '382',
#   'referer': 'http://192.168.4.161/DVWA',
#   'agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.21 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.21"'},
#  {'host': '192.168.4.25',
#   'indent': '-',
#   'user': '-',
#   'time': '22/Dec/2016:16:21:25 +0300',
#   'method': 'POST',
#   'request_path': '/index.php/component/search/ HTTP/1.1',
#   'status': '303',
#   'size': '373',
#   'referer': 'http://192.168.4.161/DVWA',
#   'agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.21 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.21"'},
#  {'host': '192.168.4.25',
#   'indent': '-',
#   'user': '-',
#   'time': '22/Dec/2016:16:26:15 +0300',
#   'method': 'POST',
#   'request_path': '/index.php/component/search/ HTTP/1.1',
#   'status': '303',
#   'size': '375',
#   'referer': '-',
#   'agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.21 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.21"'},
#  {'host': '192.168.4.25',
#   'indent': '-',
#   'user': '-',
#   'time': '22/Dec/2016:16:31:48 +0300',
#   'method': 'POST',
#   'request_path': '/index.php HTTP/1.1',
#   'status': '404',
#   'size': '3997',
#   'referer': 'http://192.168.4.161/DVWA',
#   'agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.21 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.21"'},
#  {'host': '192.168.4.25',
#   'indent': '-',
#   'user': '-',
#   'time': '22/Dec/2016:16:28:47 +0300',
#   'method': 'POST',
#   'request_path': '/index.php/component/search/ HTTP/1.1',
#   'status': '303',
#   'size': '405',
#   'referer': 'http://192.168.4.161/DVWA',
#   'agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.21 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.21"'},
#  {'host': '192.168.4.25',
#   'indent': '-',
#   'user': '-',
#   'time': '22/Dec/2016:16:20:52 +0300',
#   'method': 'POST',
#   'request_path': '/index.php/component/search/ HTTP/1.1',
#   'status': '303',
#   'size': '380',
#   'referer': '-',
#   'agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.21 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.21"'},
#  {'host': '192.168.4.25',
#   'indent': '-',
#   'user': '-',
#   'time': '22/Dec/2016:16:18:26 +0300',
#   'method': 'GET',
#   'request_path': '/media/system/js/caption.js HTTP/1.1',
#   'status': '200',
#   'size': '751',
#   'referer': "http://192.168.4.161/index.php/component/content/?wvstest=javascript:domxssExecutionSink(1,%22'%5C%22%3E%3Cxsstag%3E()locxss%22)",
#   'agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.21 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.21"'},
#  {'host': '192.168.4.25',
#   'indent': '-',
#   'user': '-',
#   'time': '22/Dec/2016:16:21:33 +0300',
#   'method': 'POST',
#   'request_path': '/index.php/component/search/ HTTP/1.1',
#   'status': '303',
#   'size': '378',
#   'referer': 'http://192.168.4.161/DVWA',
#   'agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.21 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.21"'},
#  {'host': '192.168.4.25',
#   'indent': '-',
#   'user': '-',
#   'time': '22/Dec/2016:16:25:03 +0300',
#   'method': 'POST',
#   'request_path': '/index.php/component/search/ HTTP/1.1',
#   'status': '500',
#   'size': '2023',
#   'referer': '-',
#   'agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.21 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.21"'},
#  {'host': '192.168.4.25',
#   'indent': '-',
#   'user': '-',
#   'time': '22/Dec/2016:16:38:11 +0300',
#   'method': 'POST',
#   'request_path': '/index.php/component/search/ HTTP/1.1',
#   'status': '200',
#   'size': '3053',
#   'referer': 'http://192.168.4.161/DVWA',
#   'agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.21 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.21"'},
#  {'host': '192.168.4.25',
#   'indent': '-',
#   'user': '-',
#   'time': '22/Dec/2016:16:25:59 +0300',
#   'method': 'POST',
#   'request_path': '/index.php/component/search/ HTTP/1.1',
#   'status': '303',
#   'size': '363',
#   'referer': 'http://192.168.4.161/DVWA',
#   'agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.21 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.21"'},
#  {'host': '192.168.4.25',
#   'indent': '-',
#   'user': '-',
#   'time': '22/Dec/2016:16:21:59 +0300',
#   'method': 'POST',
#   'request_path': '/index.php/component/search/ HTTP/1.1',
#   'status': '303',
#   'size': '385',
#   'referer': 'http://192.168.4.161/DVWA',
#   'agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.21 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.21"'},
#  {'host': '192.168.4.25',
#   'indent': '-',
#   'user': '-',
#   'time': '22/Dec/2016:16:32:02 +0300',
#   'method': 'GET',
#   'request_path': '/index.php/component/search/?searchword=acu4052%EF%BC%9Cs1%EF%B9%A5s2%CA%BAs3%CA%B9uca4052&ordering=oldest&searchphrase=all&areas[0]=categories HTTP/1.1',
#   'status': '200',
#   'size': '3289',
#   'referer': 'http://192.168.4.161/DVWA',
#   'agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.21 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.21"'},
#  {'host': '192.168.4.25',
#   'indent': '-',
#   'user': '-',
#   'time': '22/Dec/2016:16:24:58 +0300',
#   'method': 'POST',
#   'request_path': '/index.php/component/search/ HTTP/1.1',
#   'status': '500',
#   'size': '2055',
#   'referer': 'http://192.168.4.161/DVWA',
#   'agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.21 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.21"'},
#  {'host': '192.168.4.25',
#   'indent': '-',
#   'user': '-',
#   'time': '22/Dec/2016:16:21:55 +0300',
#   'method': 'POST',
#   'request_path': '/index.php/component/search/ HTTP/1.1',
#   'status': '303',
#   'size': '399',
#   'referer': 'http://192.168.4.161/DVWA',
#   'agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.21 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.21"'},
#  {'host': '192.168.4.25',
#   'indent': '-',
#   'user': '-',
#   'time': '22/Dec/2016:16:26:45 +0300',
#   'method': 'POST',
#   'request_path': '/index.php/component/search/ HTTP/1.1',
#   'status': '200',
#   'size': '3086',
#   'referer': 'http://192.168.4.161/DVWA',
#   'agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.21 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.21"'},
#  {'host': '192.168.4.25',
#   'indent': '-',
#   'user': '-',
#   'time': '22/Dec/2016:16:24:50 +0300',
#   'method': 'POST',
#   'request_path': '/index.php/component/search/ HTTP/1.1',
#   'status': '303',
#   'size': '382',
#   'referer': 'http://192.168.4.161/DVWA',
#   'agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.21 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.21"'},
#  {'host': '192.168.4.25',
#   'indent': '-',
#   'user': '-',
#   'time': '22/Dec/2016:16:31:01 +0300',
#   'method': 'GET',
#   'request_path': '/index.php/%24{9999410%2b9999115}/users/ HTTP/1.1',
#   'status': '404',
#   'size': '3996',
#   'referer': '-',
#   'agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.21 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.21"'},
#  {'host': '192.168.4.25',
#   'indent': '-',
#   'user': '-',
#   'time': '22/Dec/2016:16:27:56 +0300',
#   'method': 'POST',
#   'request_path': '/index.php/component/search/ HTTP/1.1',
#   'status': '303',
#   'size': '377',
#   'referer': '-',
#   'agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.21 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.21"'},
#  {'host': '192.168.4.25',
#   'indent': '-',
#   'user': '-',
#   'time': '22/Dec/2016:16:18:08 +0300',
#   'method': 'GET',
#   'request_path': '/ HTTP/1.1',
#   'status': '200',
#   'size': '3276',
#   'referer': '-',
#   'agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.21 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.21"'},
#  {'host': '192.168.4.25',
#   'indent': '-',
#   'user': '-',
#   'time': '22/Dec/2016:16:27:41 +0300',
#   'method': 'POST',
#   'request_path': '/index.php/component/search/ HTTP/1.1',
#   'status': '303',
#   'size': '367',
#   'referer': 'http://192.168.4.161/DVWA',
#   'agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.21 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.21"'},
#  {'host': '192.168.4.25',
#   'indent': '-',
#   'user': '-',
#   'time': '22/Dec/2016:16:37:44 +0300',
#   'method': 'POST',
#   'request_path': '/index.php/component/search/ HTTP/1.1',
#   'status': '200',
#   'size': '3057',
#   'referer': 'http://192.168.4.161/DVWA',
#   'agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.21 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.21"'},
#  {'host': '192.168.4.25',
#   'indent': '-',
#   'user': '-',
#   'time': '22/Dec/2016:16:27:34 +0300',
#   'method': 'GET',
#   'request_path': '/index.php/component/search/?searchword=&ordering=popular&searchphrase=any&areas[0]=categoriesacxScRiPtkzsy9922ScRiPt HTTP/1.1',
#   'status': '200',
#   'size': '3162',
#   'referer': 'http://192.168.4.161/DVWA',
#   'agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.21 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.21"'},
#  {'host': '192.168.4.25',
#   'indent': '-',
#   'user': '-',
#   'time': '22/Dec/2016:16:21:42 +0300',
#   'method': 'POST',
#   'request_path': '/index.php/component/search/ HTTP/1.1',
#   'status': '303',
#   'size': '380',
#   'referer': 'http://192.168.4.161/DVWA',
#   'agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.21 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.21"'},
#  {'host': '192.168.4.25',
#   'indent': '-',
#   'user': '-',
#   'time': '22/Dec/2016:16:34:52 +0300',
#   'method': 'GET',
#   'request_path': '/index.php/component/search/?ordering=newest&searchphrase=any&searchword=Http://testasp.vulnweb.com/t/fit.txt HTTP/1.1',
#   'status': '200',
#   'size': '3259',
#   'referer': 'http://192.168.4.161/DVWA',
#   'agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.21 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.21"'},
#  {'host': '192.168.4.25',
#   'indent': '-',
#   'user': '-',
#   'time': '22/Dec/2016:16:25:16 +0300',
#   'method': 'POST',
#   'request_path': '/index.php/component/search/ HTTP/1.1',
#   'status': '200',
#   'size': '3056',
#   'referer': 'http://192.168.4.161/DVWA',
#   'agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.21 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.21"'},
#  {'host': '192.168.4.25',
#   'indent': '-',
#   'user': '-',
#   'time': '22/Dec/2016:16:28:48 +0300',
#   'method': 'POST',
#   'request_path': '/index.php/component/search/ HTTP/1.1',
#   'status': '303',
#   'size': '408',
#   'referer': 'http://192.168.4.161/DVWA',
#   'agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.21 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.21"'},
#  {'host': '192.168.4.25',
#   'indent': '-',
#   'user': '-',
#   'time': '22/Dec/2016:16:22:18 +0300',
#   'method': 'POST',
#   'request_path': '/index.php/component/search/ HTTP/1.1',
#   'status': '200',
#   'size': '3055',
#   'referer': '-',
#   'agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.21 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.21"'},
#  {'host': '192.168.4.25',
#   'indent': '-',
#   'user': '-',
#   'time': '22/Dec/2016:16:21:56 +0300',
#   'method': 'POST',
#   'request_path': '/index.php/component/search/ HTTP/1.1',
#   'status': '303',
#   'size': '371',
#   'referer': 'http://192.168.4.161/DVWA',
#   'agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.21 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.21"'},
#  {'host': '192.168.4.25',
#   'indent': '-',
#   'user': '-',
#   'time': '22/Dec/2016:16:22:16 +0300',
#   'method': 'POST',
#   'request_path': '/index.php/component/search/ HTTP/1.1',
#   'status': '303',
#   'size': '373',
#   'referer': 'http://192.168.4.161/DVWA',
#   'agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.21 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.21"'},
#  {'host': '192.168.4.25',
#   'indent': '-',
#   'user': '-',
#   'time': '22/Dec/2016:16:28:14 +0300',
#   'method': 'POST',
#   'request_path': '/index.php/component/search/ HTTP/1.1',
#   'status': '500',
#   'size': '2035',
#   'referer': '-',
#   'agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.21 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.21"'},
#  {'host': '192.168.4.25',
#   'indent': '-',
#   'user': '-',
#   'time': '22/Dec/2016:16:26:58 +0300',
#   'method': 'POST',
#   'request_path': '/index.php/component/search/ HTTP/1.1',
#   'status': '303',
#   'size': '439',
#   'referer': 'http://192.168.4.161/DVWA',
#   'agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.21 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.21"'},
#  {'host': '192.168.4.25',
#   'indent': '-',
#   'user': '-',
#   'time': '22/Dec/2016:16:26:34 +0300',
#   'method': 'POST',
#   'request_path': '/index.php/component/search/ HTTP/1.1',
#   'status': '500',
#   'size': '2015',
#   'referer': 'http://192.168.4.161/DVWA',
#   'agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.21 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.21"'},
#  {'host': '192.168.4.25',
#   'indent': '-',
#   'user': '-',
#   'time': '22/Dec/2016:16:27:10 +0300',
#   'method': 'POST',
#   'request_path': '/index.php/component/search/ HTTP/1.1',
#   'status': '500',
#   'size': '2055',
#   'referer': 'http://192.168.4.161/DVWA',
#   'agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.21 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.21"'},
#  {'host': '192.168.4.25',
#   'indent': '-',
#   'user': '-',
#   'time': '22/Dec/2016:16:28:06 +0300',
#   'method': 'POST',
#   'request_path': '/index.php/component/search/ HTTP/1.1',
#   'status': '303',
#   'size': '376',
#   'referer': '-',
#   'agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.21 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.21"'},
#  {'host': '192.168.4.25',
#   'indent': '-',
#   'user': '-',
#   'time': '22/Dec/2016:16:32:55 +0300',
#   'method': 'POST',
#   'request_path': '/index.php HTTP/1.1',
#   'status': '303',
#   'size': '368',
#   'referer': 'http://192.168.4.161/DVWA',
#   'agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.21 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.21"'},
#  {'host': '192.168.4.25',
#   'indent': '-',
#   'user': '-',
#   'time': '22/Dec/2016:16:27:04 +0300',
#   'method': 'POST',
#   'request_path': '/index.php/component/search/ HTTP/1.1',
#   'status': '200',
#   'size': '3053',
#   'referer': '-',
#   'agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.21 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.21"'},
#  {'host': '192.168.4.25',
#   'indent': '-',
#   'user': '-',
#   'time': '22/Dec/2016:16:30:08 +0300',
#   'method': 'POST',
#   'request_path': '/index.php/component/search/ HTTP/1.1',
#   'status': '303',
#   'size': '377',
#   'referer': 'http://192.168.4.161/DVWA',
#   'agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.21 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.21"'},
#  {'host': '192.168.4.25',
#   'indent': '-',
#   'user': '-',
#   'time': '22/Dec/2016:16:37:18 +0300',
#   'method': 'GET',
#   'request_path': "/index.php/2-uncategorised/1-testsayfasi?page=&print=-1;%20waitfor%20delay%20'0:0:6'%20--%20&tmpl=component HTTP/1.1",
#   'status': '200',
#   'size': '1525',
#   'referer': 'http://192.168.4.161/DVWA',
#   'agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.21 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.21"'},
#  {'host': '192.168.4.25',
#   'indent': '-',
#   'user': '-',
#   'time': '22/Dec/2016:16:38:10 +0300',
#   'method': 'POST',
#   'request_path': '/index.php/component/users/?task=user.login HTTP/1.1',
#   'status': '200',
#   'size': '237',
#   'referer': '-',
#   'agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.21 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.21"'},
#  {'host': '192.168.4.25',
#   'indent': '-',
#   'user': '-',
#   'time': '22/Dec/2016:16:25:58 +0300',
#   'method': 'POST',
#   'request_path': '/index.php/component/search/ HTTP/1.1',
#   'status': '200',
#   'size': '3084',
#   'referer': 'http://192.168.4.161/DVWA',
#   'agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.21 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.21"'},
#  {'host': '192.168.4.25',
#   'indent': '-',
#   'user': '-',
#   'time': '22/Dec/2016:16:28:34 +0300',
#   'method': 'POST',
#   'request_path': '/index.php/component/search/ HTTP/1.1',
#   'status': '200',
#   'size': '3055',
#   'referer': '-',
#   'agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.21 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.21"'},
#  {'host': '192.168.4.25',
#   'indent': '-',
#   'user': '-',
#   'time': '22/Dec/2016:16:36:07 +0300',
#   'method': 'POST',
#   'request_path': '/index.php/component/search/ HTTP/1.1',
#   'status': '303',
#   'size': '369',
#   'referer': 'http://192.168.4.161/DVWA',
#   'agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.21 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.21"'},
#  {'host': '192.168.4.25',
#   'indent': '-',
#   'user': '-',
#   'time': '22/Dec/2016:16:20:11 +0300',
#   'method': 'POST',
#   'request_path': '/index.php/component/search/ HTTP/1.1',
#   'status': '303',
#   'size': '359',
#   'referer': 'http://192.168.4.161/DVWA',
#   'agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.21 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.21"'},
#  {'host': '192.168.4.25',
#   'indent': '-',
#   'user': '-',
#   'time': '22/Dec/2016:16:20:21 +0300',
#   'method': 'POST',
#   'request_path': '/index.php/component/search/ HTTP/1.1',
#   'status': '303',
#   'size': '381',
#   'referer': '-',
#   'agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.21 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.21"'},
#  {'host': '192.168.4.25',
#   'indent': '-',
#   'user': '-',
#   'time': '22/Dec/2016:16:35:37 +0300',
#   'method': 'POST',
#   'request_path': '/index.php/component/search/ HTTP/1.1',
#   'status': '303',
#   'size': '427',
#   'referer': 'http://192.168.4.161/DVWA',
#   'agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.21 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.21"'},
#  {'host': '192.168.4.25',
#   'indent': '-',
#   'user': '-',
#   'time': '22/Dec/2016:16:20:10 +0300',
#   'method': 'POST',
#   'request_path': '/index.php/component/search/ HTTP/1.1',
#   'status': '303',
#   'size': '365',
#   'referer': '-',
#   'agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.21 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.21"'},
#  {'host': '192.168.4.25',
#   'indent': '-',
#   'user': '-',
#   'time': '22/Dec/2016:16:34:00 +0300',
#   'method': 'GET',
#   'request_path': '/index.php/component/search/?ordering=popular&searchphrase=12345\'\\"\\\\\'\\\\\\");|]*%00{%0d%0a<%00>%bf%27\'\\xf0\\x9f\\x92\\xa9&searchword= HTTP/1.1',
#   'status': '200',
#   'size': '3104',
#   'referer': 'http://192.168.4.161/DVWA',
#   'agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.21 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.21"'},
#  {'host': '192.168.4.25',
#   'indent': '-',
#   'user': '-',
#   'time': '22/Dec/2016:16:28:25 +0300',
#   'method': 'POST',
#   'request_path': '/index.php/component/search/ HTTP/1.1',
#   'status': '303',
#   'size': '372',
#   'referer': '-',
#   'agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.21 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.21"'},
#  {'host': '192.168.4.25',
#   'indent': '-',
#   'user': '-',
#   'time': '22/Dec/2016:16:31:13 +0300',
#   'method': 'GET',
#   'request_path': '/http://hitvtXI9axeIm.bxss.me//component/search/ HTTP/1.1',
#   'status': '404',
#   'size': '538',
#   'referer': '-',
#   'agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.21 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.21"'},
#  {'host': '192.168.4.25',
#   'indent': '-',
#   'user': '-',
#   'time': '22/Dec/2016:16:36:08 +0300',
#   'method': 'GET',
#   'request_path': '/DVWA/vulnerabilities/fi?page=\'\\"()%26%25<acx><ScRiPt%20>H5NJ(9347)</ScRiPt> HTTP/1.1',
#   'status': '301',
#   'size': '736',
#   'referer': 'http://192.168.4.161/DVWA',
#   'agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.21 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.21"'},
#  {'host': '192.168.4.25',
#   'indent': '-',
#   'user': '-',
#   'time': '22/Dec/2016:16:21:50 +0300',
#   'method': 'POST',
#   'request_path': '/index.php/component/search/ HTTP/1.1',
#   'status': '303',
#   'size': '367',
#   'referer': 'http://192.168.4.161/DVWA',
#   'agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.21 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.21"'},
#  {'host': '192.168.4.25',
#   'indent': '-',
#   'user': '-',
#   'time': '22/Dec/2016:16:33:44 +0300',
#   'method': 'POST',
#   'request_path': '/index.php HTTP/1.1',
#   'status': '303',
#   'size': '369',
#   'referer': 'http://192.168.4.161/DVWA',
#   'agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.21 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.21"'},
#  {'host': '192.168.4.25',
#   'indent': '-',
#   'user': '-',
#   'time': '22/Dec/2016:16:37:00 +0300',
#   'method': 'POST',
#   'request_path': '/index.php HTTP/1.1',
#   'status': '303',
#   'size': '368',
#   'referer': 'http://192.168.4.161/DVWA',
#   'agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.21 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.21"'},
#  {'host': '192.168.4.25',
#   'indent': '-',
#   'user': '-',
#   'time': '22/Dec/2016:16:20:45 +0300',
#   'method': 'POST',
#   'request_path': '/index.php/component/search/ HTTP/1.1',
#   'status': '303',
#   'size': '361',
#   'referer': '-',
#   'agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.21 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.21"'},
#  {'host': '192.168.4.25',
#   'indent': '-',
#   'user': '-',
#   'time': '22/Dec/2016:16:32:53 +0300',
#   'method': 'POST',
#   'request_path': '/index.php HTTP/1.1',
#   'status': '303',
#   'size': '368',
#   'referer': 'http://192.168.4.161/DVWA',
#   'agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.21 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.21"'},
#  {'host': '192.168.4.25',
#   'indent': '-',
#   'user': '-',
#   'time': '22/Dec/2016:16:38:58 +0300',
#   'method': 'POST',
#   'request_path': '/index.php/component/users/?task=registration.register HTTP/1.1',
#   'status': '200',
#   'size': '237',
#   'referer': 'http://192.168.4.161/DVWA',
#   'agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.21 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.21"'},
#  {'host': '192.168.4.25',
#   'indent': '-',
#   'user': '-',
#   'time': '22/Dec/2016:16:29:12 +0300',
#   'method': 'POST',
#   'request_path': '/index.php/component/search/ HTTP/1.1',
#   'status': '200',
#   'size': '3086',
#   'referer': '-',
#   'agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.21 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.21"'},
#  {'host': '192.168.4.25',
#   'indent': '-',
#   'user': '-',
#   'time': '22/Dec/2016:16:34:35 +0300',
#   'method': 'POST',
#   'request_path': '/index.php/component/search/ HTTP/1.1',
#   'status': '200',
#   'size': '2623',
#   'referer': 'http://192.168.4.161/DVWA',
#   'agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.21 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.21"'},
#  {'host': '192.168.4.25',
#   'indent': '-',
#   'user': '-',
#   'time': '22/Dec/2016:16:24:37 +0300',
#   'method': 'POST',
#   'request_path': '/index.php/component/search/ HTTP/1.1',
#   'status': '200',
#   'size': '3089',
#   'referer': 'http://192.168.4.161/DVWA',
#   'agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.21 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.21"'},
#  {'host': '192.168.4.25',
#   'indent': '-',
#   'user': '-',
#   'time': '22/Dec/2016:16:26:42 +0300',
#   'method': 'POST',
#   'request_path': '/index.php/component/search/ HTTP/1.1',
#   'status': '303',
#   'size': '376',
#   'referer': 'http://192.168.4.161/DVWA',
#   'agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.21 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.21"'},
#  {'host': '192.168.4.25',
#   'indent': '-',
#   'user': '-',
#   'time': '22/Dec/2016:16:26:16 +0300',
#   'method': 'POST',
#   'request_path': '/index.php/component/search/ HTTP/1.1',
#   'status': '303',
#   'size': '373',
#   'referer': 'http://192.168.4.161/DVWA',
#   'agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.21 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.21"'},
#  {'host': '192.168.4.25',
#   'indent': '-',
#   'user': '-',
#   'time': '22/Dec/2016:16:38:56 +0300',
#   'method': 'POST',
#   'request_path': '/index.php/component/users/?task=registration.register HTTP/1.1',
#   'status': '200',
#   'size': '238',
#   'referer': 'http://192.168.4.161/DVWA',
#   'agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.21 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.21"'},
#  {'host': '192.168.4.25',
#   'indent': '-',
#   'user': '-',
#   'time': '22/Dec/2016:16:21:30 +0300',
#   'method': 'POST',
#   'request_path': '/index.php/component/search/ HTTP/1.1',
#   'status': '303',
#   'size': '354',
#   'referer': '-',
#   'agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.21 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.21"'},
#  {'host': '192.168.4.25',
#   'indent': '-',
#   'user': '-',
#   'time': '22/Dec/2016:16:24:59 +0300',
#   'method': 'POST',
#   'request_path': '/index.php/component/search/ HTTP/1.1',
#   'status': '303',
#   'size': '371',
#   'referer': 'http://192.168.4.161/DVWA',
#   'agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.21 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.21"'},
#  {'host': '192.168.4.25',
#   'indent': '-',
#   'user': '-',
#   'time': '22/Dec/2016:16:30:06 +0300',
#   'method': 'POST',
#   'request_path': '/index.php/component/search/ HTTP/1.1',
#   'status': '303',
#   'size': '368',
#   'referer': 'http://192.168.4.161/DVWA',
#   'agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.21 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.21"'},
#  {'host': '192.168.4.25',
#   'indent': '-',
#   'user': '-',
#   'time': '22/Dec/2016:16:40:20 +0300',
#   'method': 'POST',
#   'request_path': '/index.php/component/search/ HTTP/1.1',
#   'status': '200',
#   'size': '3087',
#   'referer': 'http://192.168.4.161/DVWA',
#   'agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.21 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.21"'},
#  {'host': '192.168.4.25',
#   'indent': '-',
#   'user': '-',
#   'time': '22/Dec/2016:16:38:29 +0300',
#   'method': 'POST',
#   'request_path': '/index.php/component/search/ HTTP/1.1',
#   'status': '200',
#   'size': '3056',
#   'referer': 'http://192.168.4.161/DVWA',
#   'agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.21 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.21"'},
#  {'host': '192.168.4.25',
#   'indent': '-',
#   'user': '-',
#   'time': '22/Dec/2016:16:27:57 +0300',
#   'method': 'POST',
#   'request_path': '/index.php/component/search/ HTTP/1.1',
#   'status': '303',
#   'size': '376',
#   'referer': 'http://192.168.4.161/DVWA',
#   'agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.21 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.21"'},
#  {'host': '192.168.4.25',
#   'indent': '-',
#   'user': '-',
#   'time': '22/Dec/2016:16:33:14 +0300',
#   'method': 'POST',
#   'request_path': '/index.php/component/search/ HTTP/1.1',
#   'status': '200',
#   'size': '3056',
#   'referer': 'http://192.168.4.161/DVWA',
#   'agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.21 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.21"'},
#  {'host': '192.168.4.25',
#   'indent': '-',
#   'user': '-',
#   'time': '22/Dec/2016:16:35:58 +0300',
#   'method': 'GET',
#   'request_path': '/index.php/component/search/?ordering=popular&searchphrase=any&searchword=/www.vulnweb.com HTTP/1.1',
#   'status': '200',
#   'size': '3166',
#   'referer': '-',
#   'agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.21 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.21"'},
#  {'host': '192.168.4.25',
#   'indent': '-',
#   'user': '-',
#   'time': '22/Dec/2016:16:26:52 +0300',
#   'method': 'POST',
#   'request_path': '/index.php/component/search/ HTTP/1.1',
#   'status': '303',
#   'size': '380',
#   'referer': '-',
#   'agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.21 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.21"'},
#  {'host': '192.168.4.25',
#   'indent': '-',
#   'user': '-',
#   'time': '22/Dec/2016:16:22:54 +0300',
#   'method': 'POST',
#   'request_path': '/index.php/component/search/ HTTP/1.1',
#   'status': '303',
#   'size': '387',
#   'referer': 'http://192.168.4.161/DVWA',
#   'agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.21 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.21"'},
#  {'host': '192.168.4.25',
#   'indent': '-',
#   'user': '-',
#   'time': '22/Dec/2016:16:27:23 +0300',
#   'method': 'POST',
#   'request_path': '/index.php/component/search/ HTTP/1.1',
#   'status': '303',
#   'size': '362',
#   'referer': '-',
#   'agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.21 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.21"'},
#  {'host': '192.168.4.25',
#   'indent': '-',
#   'user': '-',
#   'time': '22/Dec/2016:16:24:48 +0300',
#   'method': 'POST',
#   'request_path': '/index.php/component/search/ HTTP/1.1',
#   'status': '303',
#   'size': '379',
#   'referer': 'http://192.168.4.161/DVWA',
#   'agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.21 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.21"'},
#  {'host': '192.168.4.25',
#   'indent': '-',
#   'user': '-',
#   'time': '22/Dec/2016:16:28:01 +0300',
#   'method': 'POST',
#   'request_path': '/index.php/component/search/ HTTP/1.1',
#   'status': '303',
#   'size': '372',
#   'referer': '-',
#   'agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.21 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.21"'},
#  {'host': '192.168.4.25',
#   'indent': '-',
#   'user': '-',
#   'time': '22/Dec/2016:16:18:14 +0300',
#   'method': 'GET',
#   'request_path': '/ HTTP/1.1',
#   'status': '200',
#   'size': '3351',
#   'referer': '-',
#   'agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.21 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.21"'},
#  {'host': '192.168.4.25',
#   'indent': '-',
#   'user': '-',
#   'time': '22/Dec/2016:16:37:19 +0300',
#   'method': 'POST',
#   'request_path': '/index.php/component/search/ HTTP/1.1',
#   'status': '200',
#   'size': '3054',
#   'referer': 'http://192.168.4.161/DVWA',
#   'agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.21 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.21"'},
#  {'host': '192.168.4.25',
#   'indent': '-',
#   'user': '-',
#   'time': '22/Dec/2016:16:19:00 +0300',
#   'method': 'POST',
#   'request_path': '/index.php HTTP/1.1',
#   'status': '200',
#   'size': '1837',
#   'referer': 'http://192.168.4.161/DVWA',
#   'agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.21 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.21"'},
#  {'host': '192.168.4.25',
#   'indent': '-',
#   'user': '-',
#   'time': '22/Dec/2016:16:25:49 +0300',
#   'method': 'POST',
#   'request_path': '/index.php/component/search/ HTTP/1.1',
#   'status': '303',
#   'size': '380',
#   'referer': 'http://192.168.4.161/DVWA',
#   'agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.21 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.21"'},
#  {'host': '192.168.4.25',
#   'indent': '-',
#   'user': '-',
#   'time': '22/Dec/2016:16:27:42 +0300',
#   'method': 'POST',
#   'request_path': '/index.php/component/search/ HTTP/1.1',
#   'status': '303',
#   'size': '365',
#   'referer': '-',
#   'agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.21 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.21"'},
#  {'host': '192.168.4.25',
#   'indent': '-',
#   'user': '-',
#   'time': '22/Dec/2016:16:19:12 +0300',
#   'method': 'GET',
#   'request_path': '/index.php/component/content/?format=feed&type=atom&view=featured<body%20onload=p3oZ(9741)> HTTP/1.1',
# ...
#   'status': '404',
#   'size': '582',
#   'referer': 'http://192.168.4.161/DVWA',
#   'agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.21 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.21"'},
#  {'host': '192.168.4.25',
#   'indent': '-',
#   'user': '-',
#   'time': '22/Dec/2016:16:23:28 +0300',
#   'method': 'POST',
#   'request_path': '/index.php/component/search/ HTTP/1.1',
#   'status': '200',
#   'size': '3053',
#   'referer': 'http://192.168.4.161/DVWA',
#   'agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.21 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.21"'},
#  {'host': '192.168.4.25',
#   'indent': '-',
#   'user': '-',
#   'time': '22/Dec/2016:16:27:59 +0300',
#   'method': 'POST',
#   'request_path': '/index.php/component/search/ HTTP/1.1',
#   'status': '303',
#   'size': '370',
#   'referer': '-',
#   'agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.21 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.21"'},
#  {'host': '192.168.4.25',
#   'indent': '-',
#   'user': '-',
#   'time': '22/Dec/2016:16:35:13 +0300',
#   'method': 'POST',
#   'request_path': '/index.php/component/search/ HTTP/1.1',
#   'status': '303',
#   'size': '385',
#   'referer': 'http://192.168.4.161/DVWA',
#   'agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.21 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.21"'},
#  {'host': '192.168.4.25',
#   'indent': '-',
#   'user': '-',
#   'time': '22/Dec/2016:16:21:38 +0300',
#   'method': 'POST',
#   'request_path': '/index.php/component/search/ HTTP/1.1',
#   'status': '303',
#   'size': '407',
#   'referer': 'http://192.168.4.161/DVWA',
#   'agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.21 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.21"'},
#  {'host': '192.168.4.25',
#   'indent': '-',
#   'user': '-',
#   'time': '22/Dec/2016:16:23:20 +0300',
#   'method': 'POST',
#   'request_path': '/index.php/component/search/ HTTP/1.1',
#   'status': '303',
#   'size': '437',
#   'referer': 'http://192.168.4.161/DVWA',
#   'agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.21 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.21"'},
#  {'host': '192.168.4.25',
#   'indent': '-',
#   'user': '-',
#   'time': '22/Dec/2016:16:23:56 +0300',
#   'method': 'POST',
#   'request_path': '/index.php/component/search/ HTTP/1.1',
#   'status': '303',
#   'size': '377',
#   'referer': 'http://192.168.4.161/DVWA',
#   'agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.21 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.21"'},
#  {'host': '192.168.4.25',
#   'indent': '-',
#   'user': '-',
#   'time': '22/Dec/2016:16:30:29 +0300',
#   'method': 'POST',
#   'request_path': '/index.php/component/search/ HTTP/1.1',
#   'status': '303',
#   'size': '481',
#   'referer': 'http://192.168.4.161/DVWA',
#   'agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.21 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.21"'},
#  {'host': '192.168.4.25',
#   'indent': '-',
#   'user': '-',
#   'time': '22/Dec/2016:16:22:31 +0300',
#   'method': 'POST',
#   'request_path': '/index.php/component/search/ HTTP/1.1',
#   'status': '303',
#   'size': '368',
#   'referer': 'http://192.168.4.161/DVWA',
#   'agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.21 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.21"'},
#  {'host': '192.168.4.25',
#   'indent': '-',
#   'user': '-',
#   'time': '22/Dec/2016:16:19:01 +0300',
#   'method': 'POST',
#   'request_path': '/index.php HTTP/1.1',
#   'status': '200',
#   'size': '1813',
#   'referer': 'http://192.168.4.161/DVWA',
#   'agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.21 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.21"'},
#  {'host': '192.168.4.25',
#   'indent': '-',
#   'user': '-',
#   'time': '22/Dec/2016:16:22:10 +0300',
#   'method': 'POST',
#   'request_path': '/index.php/component/search/ HTTP/1.1',
#   'status': '303',
#   'size': '394',
#   'referer': '-',
#   'agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.21 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.21"'},
#  {'host': '192.168.4.25',
#   'indent': '-',
#   'user': '-',
#   'time': '22/Dec/2016:16:36:34 +0300',
#   'method': 'POST',
#   'request_path': '/index.php/component/search/ HTTP/1.1',
#   'status': '303',
#   'size': '371',
#   'referer': 'http://192.168.4.161/DVWA',
#   'agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.21 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.21"'},
#  {'host': '192.168.4.25',
#   'indent': '-',
#   'user': '-',
#   'time': '22/Dec/2016:16:29:09 +0300',
#   'method': 'POST',
#   'request_path': '/index.php/component/search/ HTTP/1.1',
#   'status': '303',
#   'size': '353',
#   'referer': 'http://192.168.4.161/DVWA',
#   'agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.21 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.21"'},
#  {'host': '192.168.4.25',
#   'indent': '-',
#   'user': '-',
#   'time': '22/Dec/2016:16:27:43 +0300',
#   'method': 'POST',
#   'request_path': '/index.php/component/search/ HTTP/1.1',
#   'status': '500',
#   'size': '2011',
#   'referer': '-',
#   'agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.21 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.21"'},
#  {'host': '192.168.4.25',
#   'indent': '-',
#   'user': '-',
#   'time': '22/Dec/2016:16:35:11 +0300',
#   'method': 'GET',
#   'request_path': "/index.php/component/search/?ordering=newest&searchphrase=any&searchword=DfRBpxgY';select%20pg_sleep(14);%20--%20 HTTP/1.1",
#   'status': '200',
#   'size': '3261',
#   'referer': 'http://192.168.4.161/DVWA',
#   'agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.21 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.21"'},
#  {'host': '192.168.4.25',
#   'indent': '-',
#   'user': '-',
#   'time': '22/Dec/2016:16:29:25 +0300',
#   'method': 'POST',
#   'request_path': '/index.php/component/search/ HTTP/1.1',
#   'status': '200',
#   'size': '2578',
#   'referer': 'http://192.168.4.161/DVWA',
#   'agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.21 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.21"'},
#  {'host': '192.168.4.25',
#   'indent': '-',
#   'user': '-',
#   'time': '22/Dec/2016:16:22:22 +0300',
#   'method': 'POST',
#   'request_path': '/index.php/component/search/ HTTP/1.1',
#   'status': '303',
#   'size': '395',
#   'referer': '-',
#   'agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.21 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.21"'},
#  {'host': '192.168.4.25',
#   'indent': '-',
#   'user': '-',
#   'time': '22/Dec/2016:16:38:52 +0300',
#   'method': 'POST',
#   'request_path': '/index.php/component/users/?task=registration.register HTTP/1.1',
#   'status': '404',
#   'size': '3990',
#   'referer': '-',
#   'agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.21 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.21"'},
#  {'host': '192.168.4.25',
#   'indent': '-',
#   'user': '-',
#   'time': '22/Dec/2016:16:21:15 +0300',
#   'method': 'POST',
#   'request_path': '/index.php/component/search/ HTTP/1.1',
#   'status': '303',
#   'size': '368',
#   'referer': 'http://192.168.4.161/DVWA',
#   'agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.21 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.21"'},
#  {'host': '192.168.4.25',
#   'indent': '-',
#   'user': '-',
#   'time': '22/Dec/2016:16:40:22 +0300',
#   'method': 'POST',
#   'request_path': '/index.php/component/users/?task=user.login HTTP/1.1',
#   'status': '303',
#   'size': '385',
#   'referer': 'http://192.168.4.161/DVWA',
#   'agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.21 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.21"'},
#  {'host': '192.168.4.25',
#   'indent': '-',
#   'user': '-',
#   'time': '22/Dec/2016:16:35:49 +0300',
#   'method': 'GET',
#   'request_path': '/index.php/component/search/?searchword=\'\\"()&%kzsy(9138)=&ordering=newest&searchphrase=any&areas[0]=contacts HTTP/1.1',
#   'status': '200',
#   'size': '3190',
#   'referer': 'http://192.168.4.161/DVWA',
#   'agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.21 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.21"'},
#  {'host': '192.168.4.25',
#   'indent': '-',
#   'user': '-',
#   'time': '22/Dec/2016:16:22:56 +0300',
#   'method': 'POST',
#   'request_path': '/index.php/component/search/ HTTP/1.1',
#   'status': '303',
#   'size': '400',
#   'referer': '-',
#   'agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.21 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.21"'},
#  {'host': '192.168.4.25',
#   'indent': '-',
#   'user': '-',
#   'time': '22/Dec/2016:16:30:41 +0300',
#   'method': 'POST',
#   'request_path': '/index.php/component/search/ HTTP/1.1',
#   'status': '303',
#   'size': '375',
#   'referer': 'http://192.168.4.161/DVWA',
#   'agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.21 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.21"'},
#  {'host': '192.168.4.25',
#   'indent': '-',
#   'user': '-',
#   'time': '22/Dec/2016:16:34:21 +0300',
#   'method': 'POST',
#   'request_path': '/index.php/component/search/ HTTP/1.1',
#   'status': '303',
#   'size': '357',
#   'referer': 'http://192.168.4.161/DVWA',
#   'agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.21 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.21"'},
#  {'host': '192.168.4.25',
#   'indent': '-',
#   'user': '-',
#   'time': '22/Dec/2016:16:25:48 +0300',
#   'method': 'POST',
#   'request_path': '/index.php/component/search/ HTTP/1.1',
#   'status': '303',
#   'size': '360',
#   'referer': 'http://192.168.4.161/DVWA',
#   'agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.21 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.21"'},
#  {'host': '192.168.4.25',
#   'indent': '-',
#   'user': '-',
#   'time': '22/Dec/2016:16:27:36 +0300',
#   'method': 'POST',
#   'request_path': '/index.php/component/search/ HTTP/1.1',
#   'status': '500',
#   'size': '2011',
#   'referer': '-',
#   'agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.21 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.21"'},
#  {'host': '192.168.4.25',
#   'indent': '-',
#   'user': '-',
#   'time': '22/Dec/2016:16:34:59 +0300',
#   'method': 'GET',
#   'request_path': "/index.php/component/search/?ordering=category&searchphrase=all&searchword=Zvq1N0Q0';%20waitfor%20delay%20'0:0:6'%20--%20 HTTP/1.1",
#   'status': '200',
#   'size': '3263',
#   'referer': 'http://192.168.4.161/DVWA',
#   'agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.21 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.21"'},
#  {'host': '192.168.4.25',
#   'indent': '-',
#   'user': '-',
#   'time': '22/Dec/2016:16:19:04 +0300',
#   'method': 'POST',
#   'request_path': '/index.php HTTP/1.1',
#   'status': '200',
#   'size': '1835',
#   'referer': 'http://192.168.4.161/DVWA',
#   'agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.21 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.21"'},
#  {'host': '192.168.4.25',
#   'indent': '-',
#   'user': '-',
#   'time': '22/Dec/2016:16:28:36 +0300',
#   'method': 'GET',
#   'request_path': '/index.php/component/users/?view=%f0\'\'%f0\\"\\" HTTP/1.1',
#   'status': '500',
#   'size': '2043',
#   'referer': 'http://192.168.4.161/DVWA',
#   'agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.21 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.21"'},
#  {'host': '192.168.4.25',
#   'indent': '-',
#   'user': '-',
#   'time': '22/Dec/2016:16:31:31 +0300',
#   'method': 'POST',
#   'request_path': '/index.php HTTP/1.1',
#   'status': '200',
#   'size': '237',
#   'referer': 'http://192.168.4.161/DVWA',
#   'agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.21 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.21"'},
#  {'host': '192.168.4.25',
#   'indent': '-',
#   'user': '-',
#   'time': '22/Dec/2016:16:21:07 +0300',
#   'method': 'POST',
#   'request_path': '/index.php/component/search/ HTTP/1.1',
#   'status': '303',
#   'size': '354',
#   'referer': '-',
#   'agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.21 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.21"'},
#  {'host': '192.168.4.25',
#   'indent': '-',
#   'user': '-',
#   'time': '22/Dec/2016:16:23:52 +0300',
#   'method': 'POST',
#   'request_path': '/index.php/component/search/ HTTP/1.1',
#   'status': '500',
#   'size': '2017',
#   'referer': '-',
#   'agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.21 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.21"'},
#  {'host': '192.168.4.25',
#   'indent': '-',
#   'user': '-',
#   'time': '22/Dec/2016:16:38:33 +0300',
#   'method': 'POST',
#   'request_path': '/index.php/component/users/?task=\'\\"()%26%25<acx><ScRiPt%20>y3iC(9140)</ScRiPt> HTTP/1.1',
#   'status': '200',
#   'size': '2807',
#   'referer': 'http://192.168.4.161/DVWA',
#   'agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.21 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.21"'},
#  {'host': '192.168.4.25',
#   'indent': '-',
#   'user': '-',
#   'time': '22/Dec/2016:16:19:26 +0300',
#   'method': 'GET',
#   'request_path': '/index.php/component/content/category/2-uncategorised HTTP/1.1',
#   'status': '200',
#   'size': '3476',
#   'referer': 'http://192.168.4.161/DVWA',
#   'agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.21 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.21"'},
#  {'host': '192.168.4.25',
#   'indent': '-',
#   'user': '-',
#   'time': '22/Dec/2016:16:28:26 +0300',
#   'method': 'POST',
#   'request_path': '/index.php/component/search/ HTTP/1.1',
#   'status': '303',
#   'size': '381',
#   'referer': 'http://192.168.4.161/DVWA',
#   'agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.21 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.21"'},
#  {'host': '192.168.4.25',
#   'indent': '-',
#   'user': '-',
#   'time': '22/Dec/2016:16:27:18 +0300',
#   'method': 'POST',
#   'request_path': '/index.php/component/search/ HTTP/1.1',
#   'status': '303',
#   'size': '355',
#   'referer': 'http://192.168.4.161/DVWA',
#   'agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.21 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.21"'},
#  {'host': '192.168.4.25',
#   'indent': '-',
#   'user': '-',
#   'time': '22/Dec/2016:16:26:49 +0300',
#   'method': 'POST',
#   'request_path': '/index.php/component/search/ HTTP/1.1',
#   'status': '303',
#   'size': '356',
#   'referer': 'http://192.168.4.161/DVWA',
#   'agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.21 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.21"'},
#  {'host': '192.168.4.25',
#   'indent': '-',
#   'user': '-',
#   'time': '22/Dec/2016:16:27:47 +0300',
#   'method': 'POST',
#   'request_path': '/index.php/component/search/ HTTP/1.1',
#   'status': '200',
#   'size': '3053',
#   'referer': '-',
#   'agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.21 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.21"'},
#  {'host': '192.168.4.25',
#   'indent': '-',
#   'user': '-',
#   'time': '22/Dec/2016:16:25:37 +0300',
#   'method': 'POST',
#   'request_path': '/index.php/component/search/ HTTP/1.1',
#   'status': '303',
#   'size': '374',
#   'referer': '-',
#   'agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.21 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.21"'},
#  {'host': '192.168.4.25',
#   'indent': '-',
#   'user': '-',
#   'time': '22/Dec/2016:16:35:38 +0300',
#   'method': 'GET',
#   'request_path': '/index.php/component/search/?ordering=newest&searchphrase=any&searchword= HTTP/1.1',
#   'status': '200',
#   'size': '3109',
#   'referer': 'http://192.168.4.161/DVWA',
#   'agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.21 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.21"'},
#  {'host': '192.168.4.25',
#   'indent': '-',
#   'user': '-',
#   'time': '22/Dec/2016:16:23:07 +0300',
#   'method': 'POST',
#   'request_path': '/index.php/component/search/ HTTP/1.1',
#   'status': '303',
#   'size': '399',
#   'referer': '-',
#   'agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.21 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.21"'},
#  {'host': '192.168.4.25',
#   'indent': '-',
#   'user': '-',
#   'time': '22/Dec/2016:16:33:52 +0300',
#   'method': 'GET',
#   'request_path': '/index.php/component/search/?ordering=/.././.././.././.././.././.././.././../etc/./passwd%2500&searchphrase=any&searchword= HTTP/1.1',
#   'status': '200',
#   'size': '3128',
#   'referer': 'http://192.168.4.161/DVWA',
#   'agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.21 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.21"'},
#  ...]

# %%
csv_columns = ['host','indent','user','time','method','request_path','status','size','referer','agent']
csv_file = "acunetix.csv"
try:
    with open(csv_file, 'w') as csvfile:
        writer = csv.DictWriter(csvfile, fieldnames=csv_columns)
        writer.writeheader()
        for df in data:
            writer.writerow(df)
except IOError:
    print("I/O error")

# %%
df = pd.read_csv("data/acunetix.csv")

# %%
df
# Out:
#               host indent user                        time method  \
# 0     192.168.4.25      -    -  22/Dec/2016:16:30:52 +0300   POST
# 1     192.168.4.25      -    -  22/Dec/2016:16:29:05 +0300   POST
# 2     192.168.4.25      -    -  22/Dec/2016:16:28:53 +0300   POST
# 3     192.168.4.25      -    -  22/Dec/2016:16:32:50 +0300   POST
# 4     192.168.4.25      -    -  22/Dec/2016:16:29:13 +0300   POST
# ...            ...    ...  ...                         ...    ...
# 6534  192.168.4.25      -    -  22/Dec/2016:16:22:11 +0300   POST
# 6535  192.168.4.25      -    -  22/Dec/2016:16:33:44 +0300   POST
# 6536  192.168.4.25      -    -  22/Dec/2016:16:23:07 +0300   POST
# 6537  192.168.4.25      -    -  22/Dec/2016:16:32:54 +0300   POST
# 6538  192.168.4.25      -    -  22/Dec/2016:16:20:55 +0300   POST
#
#                                request_path  status  size  \
# 0         /administrator/index.php HTTP/1.1     303   382
# 1     /index.php/component/search/ HTTP/1.1     500  2011
# 2     /index.php/component/search/ HTTP/1.1     303   374
# 3     /index.php/component/search/ HTTP/1.1     200  3054
# 4     /index.php/component/search/ HTTP/1.1     200  3056
# ...                                     ...     ...   ...
# 6534  /index.php/component/search/ HTTP/1.1     303   376
# 6535  /index.php/component/search/ HTTP/1.1     303   417
# 6536  /index.php/component/search/ HTTP/1.1     303   393
# 6537  /index.php/component/search/ HTTP/1.1     200  3054
# 6538  /index.php/component/search/ HTTP/1.1     303   363
#
#                         referer  \
# 0     http://192.168.4.161/DVWA
# 1                             -
# 2     http://192.168.4.161/DVWA
# 3     http://192.168.4.161/DVWA
# 4                             -
# ...                         ...
# 6534  http://192.168.4.161/DVWA
# 6535  http://192.168.4.161/DVWA
# 6536  http://192.168.4.161/DVWA
# 6537  http://192.168.4.161/DVWA
# 6538                          -
#
#                                                   agent
# 0     Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...
# 1     Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...
# 2     Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...
# 3     Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...
# 4     Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...
# ...                                                 ...
# 6534  Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...
# 6535  Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...
# 6536  Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...
# 6537  Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...
# 6538  Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...
#
# [6539 rows x 10 columns]

# %%
df_host_unique = df.groupby('host').count()

# %%
df_host_unique
# Out:
#               indent  user  time  method  request_path  status  size  referer  \
# host
# 192.168.4.25    6539  6539  6539    6539          6539    6539  6539     6539
#
#               agent
# host
# 192.168.4.25   6539

# %%
df_method_unique =df.groupby('method').count()

# %%
df_method_unique
# Out:
#         host  indent  user  time  request_path  status  size  referer  agent
# method
# GET     1040    1040  1040  1040          1040    1040  1040     1040   1040
# POST    5499    5499  5499  5499          5499    5499  5499     5499   5499

# %%
df_status_unique = df.groupby('status').count()

# %%
df_status_unique
# Out:
#         host  indent  user  time  method  request_path  size  referer  agent
# status
# 200     2036    2036  2036  2036    2036          2036  2036     2036   2036
# 301       18      18    18    18      18            18    18       18     18
# 302       99      99    99    99      99            99    99       99     99
# 303     3407    3407  3407  3407    3407          3407  3407     3407   3407
# 400       12      12    12    12      12            12    12       12     12
# 403        3       3     3     3       3             3     3        3      3
# 404      258     258   258   258     258           258   258      258    258
# 500      706     706   706   706     706           706   706      706    706

# %%
size_summary = df['size'].describe()

# %%
size_summary
# Out:
# count     6539.000000
# mean      1274.866493
# std       1882.247923
# min        223.000000
# 25%        373.000000
# 50%        399.000000
# 75%       2045.000000
# max      68451.000000
# Name: size, dtype: float64

# %%
import pyspark.sql.functions as F

# %%
# df

# %%
# (df.agg(F.min(df['size']).alias('min_content_size'),
#              F.max(df['size']).alias('max_content_size'),
#              F.mean(df['size']).alias('mean_content_size'),
#              F.stddev(df['size']).alias('std_content_size'),
#              F.count(df['size']).alias('count_content_size')).toPandas())

# %%
status_freq_df=(df
              .groupby('status')
              .count())
print("Total distinct HTTP Status codes:",status_freq_df)
# Out:
# Total distinct HTTP Status codes:         host  indent  user  time  method  request_path  size  referer  agent
# status
# 200     2036    2036  2036  2036    2036          2036  2036     2036   2036
# 301       18      18    18    18      18            18    18       18     18
# 302       99      99    99    99      99            99    99       99     99
# 303     3407    3407  3407  3407    3407          3407  3407     3407   3407
# 400       12      12    12    12      12            12    12       12     12
# 403        3       3     3     3       3             3     3        3      3
# 404      258     258   258   258     258           258   258      258    258
# 500      706     706   706   706     706           706   706      706    706

# %%
status_freq_pd_df = (status_freq_df
                         .sort_values(by=['host'],
                                      ascending=False))
status_freq_pd_df['count'] = status_freq_pd_df['host']

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
# %matplot inline
# Out:
# UsageError: Line magic function `%matplot` not found.

# %%
sns.catplot(x='status',y='count',data=)
